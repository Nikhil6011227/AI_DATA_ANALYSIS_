# %%
# Question: Power Transformation (Box-Cox) Method
# Description: Use Box-Cox transformation to stabilize variance and make the data more normal.


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import boxcox
from scipy.stats import shapiro

# Generate sample skewed data (strictly positive)
data = np.random.exponential(scale=2, size=1000) + 1  # shift to ensure all > 0

# Original data distribution
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue')
plt.title("Original Data")

# Apply Box-Cox transformation
data_boxcox, fitted_lambda = boxcox(data)

# Transformed data distribution
plt.subplot(1, 2, 2)
plt.hist(data_boxcox, bins=30, color='lightgreen')
plt.title(f"Box-Cox Transformed Data\nLambda: {fitted_lambda:.2f}")

plt.tight_layout()
plt.show()

# Optional: Test normality before and after transformation
stat_orig, p_orig = shapiro(data)
stat_boxcox, p_boxcox = shapiro(data_boxcox)

print(f"Original Data Shapiro-Wilk p-value: {p_orig:.4f}")
print(f"Box-Cox Data Shapiro-Wilk p-value: {p_boxcox:.4f}")
# Out:
# Original Data Shapiro-Wilk p-value: 0.0000
# Box-Cox Data Shapiro-Wilk p-value: 0.0000
